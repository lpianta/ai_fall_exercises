# %%
# importing libraries

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import QuantileTransformer
from sklearn.compose import ColumnTransformer
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from optuna.samplers import TPESampler

import optuna

# %%
# loading data

data = pd.read_csv('cereal.csv')
data.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
# defining X and y

X = data.drop('rating', axis=1)
y = data['rating']

# %%
cat_columns = ['mfr', 'type']
num_columns = X.select_dtypes(include=np.number).columns.tolist()

# %%
# splitting data in train and validation

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# creating preprocessor

cat_transformer = OneHotEncoder(handle_unknown='ignore')
num_transformer = QuantileTransformer(n_quantiles=100, output_distribution='normal')



preprocessor = ColumnTransformer(
        transformers=[
            ('num', num_transformer, num_columns),
            ('cat', cat_transformer, cat_columns)
        ])

# %%
# preprocessing data

X_train = preprocessor.fit_transform(X_train)
X_val = preprocessor.transform(X_val)
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/preprocessing/_data.py:2615: UserWarning: n_quantiles (100) is greater than the total number of samples (51). n_quantiles is set to n_samples.
#   % (self.n_quantiles, n_samples))

# %%
def objective(trial):
    model = keras.models.Sequential()
    model.add(
        keras.layers.Dense(
            50,
            activation=trial.suggest_categorical("activation", ["relu", "linear", 'swish']),
            input_shape=[21],
            ))
    model.add(
        keras.layers.Dense(10,
        activation=trial.suggest_categorical("activation", ["relu", "linear", 'swish']),)
    )
    model.add(
        keras.layers.Dense(1)
    )
    # defining suggestion for learning rate and optimizer
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])

    if optimizer_name=="Adam":
        optimizer = Adam(learning_rate=lr)
    elif optimizer_name=="RMSprop":
        optimizer = RMSprop(learning_rate=lr)
    elif optimizer_name=="SGD":
        optimizer = SGD(learning_rate=lr)
    
    # compiling model
    model.compile(
        loss="mae", optimizer=optimizer
    )

    #fitting model
    model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        shuffle=True,
        batch_size=32,
        epochs=10,
        verbose=False,
    )

    score = model.evaluate(X_val, y_val, verbose=0)
    return score

# %%
# create Optuna study

study = optuna.create_study(direction="minimize", sampler=TPESampler(multivariate=True))
study.optimize(objective, n_trials=100, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# /root/venv/lib/python3.7/site-packages/optuna/samplers/_tpe/sampler.py:191: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   ExperimentalWarning,
# [I 2021-03-01 16:45:43,533] A new study created in memory with name: no-name-74b5a9ae-88d7-4862-b888-bd5686f9e6d5
# [I 2021-03-01 16:45:44,356] Trial 0 finished with value: 7.599639415740967 and parameters: {'activation': 'linear', 'lr': 0.047618409677743265, 'optimizer': 'Adam'}. Best is trial 0 with value: 7.599639415740967.
# [I 2021-03-01 16:45:45,156] Trial 1 finished with value: 42.255958557128906 and parameters: {'activation': 'linear', 'lr': 0.00018470009306643094, 'optimizer': 'Adam'}. Best is trial 0 with value: 7.599639415740967.
# [I 2021-03-01 16:45:45,877] Trial 2 finished with value: 42.633541107177734 and parameters: {'activation': 'relu', 'lr': 3.634656181437189e-05, 'optimizer': 'SGD'}. Best is trial 0 with value: 7.599639415740967.
# [I 2021-03-01 16:45:46,593] Trial 3 finished with value: 40.67893981933594 and parameters: {'activation': 'relu', 'lr': 0.001646895871318738, 'optimizer': 'SGD'}. Best is trial 0 with value: 7.599639415740967.
# [I 2021-03-01 16:45:47,697] Trial 4 finished with value: 41.345333099365234 and parameters: {'activation': 'swish', 'lr': 9.278914315660318e-05, 'optimizer': 'SGD'}. Best is trial 0 with value: 7.599639415740967.
 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:48,947] Trial 76 finished with value: 41.43340301513672 and parameters: {'activation': 'linear', 'lr': 0.08916764177019273, 'optimizer': 'SGD'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:49,771] Trial 77 finished with value: 5.410433769226074 and parameters: {'activation': 'linear', 'lr': 0.09524277889098982, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:50,598] Trial 78 finished with value: 6.397595405578613 and parameters: {'activation': 'relu', 'lr': 0.0752641344619306, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:51,426] Trial 79 finished with value: 6.565550804138184 and parameters: {'activation': 'linear', 'lr': 0.09112618715722018, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:52,252] Trial 80 finished with value: 17.37146759033203 and parameters: {'activation': 'linear', 'lr': 0.013336130001624296, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:53,085] Trial 81 finished with value: 42.920494079589844 and parameters: {'activation': 'relu', 'lr': 0.00012069465237122549, 'optimizer': 'SGD'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:53,905] Trial 82 finished with value: 6.271004676818848 and parameters: {'activation': 'linear', 'lr': 0.09422018057221583, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:54,692] Trial 83 finished with value: 5.4923577308654785 and parameters: {'activation': 'linear', 'lr': 0.08587212851320374, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:55,931] Trial 84 finished with value: 6.013641357421875 and parameters: {'activation': 'linear', 'lr': 0.08314319323630417, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:56,725] Trial 85 finished with value: 6.725002765655518 and parameters: {'activation': 'linear', 'lr': 0.09907720284987925, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:57,557] Trial 86 finished with value: 8.59969425201416 and parameters: {'activation': 'swish', 'lr': 0.03559659497089429, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:58,328] Trial 87 finished with value: 8.824529647827148 and parameters: {'activation': 'linear', 'lr': 0.02196984558140398, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:46:59,111] Trial 88 finished with value: 6.7056355476379395 and parameters: {'activation': 'linear', 'lr': 0.09161723187870655, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:00,264] Trial 89 finished with value: 11.482365608215332 and parameters: {'activation': 'linear', 'lr': 0.021324157792228658, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:01,589] Trial 90 finished with value: 10.80379867553711 and parameters: {'activation': 'linear', 'lr': 0.026527400690379583, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:02,778] Trial 91 finished with value: 7.6760029792785645 and parameters: {'activation': 'linear', 'lr': 0.09364891627575589, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:03,656] Trial 92 finished with value: 7.51369047164917 and parameters: {'activation': 'linear', 'lr': 0.09349789133792946, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:04,468] Trial 93 finished with value: 4.5865702629089355 and parameters: {'activation': 'linear', 'lr': 0.09981888558291895, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:05,279] Trial 94 finished with value: 6.9745378494262695 and parameters: {'activation': 'linear', 'lr': 0.0915051269760109, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:06,093] Trial 95 finished with value: 6.069162368774414 and parameters: {'activation': 'linear', 'lr': 0.08677853152252986, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:06,913] Trial 96 finished with value: 8.860037803649902 and parameters: {'activation': 'linear', 'lr': 0.09783419710988478, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:07,712] Trial 97 finished with value: 41.46634292602539 and parameters: {'activation': 'swish', 'lr': 1.0483611192495765e-05, 'optimizer': 'SGD'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:08,529] Trial 98 finished with value: 10.102643966674805 and parameters: {'activation': 'linear', 'lr': 0.02066516340628995, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# [I 2021-03-01 16:47:09,399] Trial 99 finished with value: 10.141007423400879 and parameters: {'activation': 'linear', 'lr': 0.026434793970571024, 'optimizer': 'Adam'}. Best is trial 64 with value: 3.7747297286987305.
# Number of finished trials: 100
# Best trial:
#   Value: 3.7747297286987305
#   Params:
#     activation: linear
#     lr: 0.08789065282856405
#     optimizer: Adam

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9f2954cd-f149-4d4f-a4b0-a1e3eb6d921f' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
