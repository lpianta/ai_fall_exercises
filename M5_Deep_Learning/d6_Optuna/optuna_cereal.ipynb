# %%
# importing libraries

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import QuantileTransformer
from sklearn.compose import ColumnTransformer
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from optuna.samplers import TPESampler

import optuna

# %%
# loading data

data = pd.read_csv('cereal.csv')
data.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
# defining X and y

X = data.drop('rating', axis=1)
y = data['rating']

# %%
cat_columns = ['mfr', 'type']
num_columns = X.select_dtypes(include=np.number).columns.tolist()

# %%
# splitting data in train and validation

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# creating preprocessor

cat_transformer = OneHotEncoder(handle_unknown='ignore')
num_transformer = QuantileTransformer(n_quantiles=100, output_distribution='normal')



preprocessor = ColumnTransformer(
        transformers=[
            ('num', num_transformer, num_columns),
            ('cat', cat_transformer, cat_columns)
        ])

# %%
# preprocessing data

X_train = preprocessor.fit_transform(X_train)
X_val = preprocessor.transform(X_val)
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/sklearn/preprocessing/_data.py:2615: UserWarning: n_quantiles (100) is greater than the total number of samples (51). n_quantiles is set to n_samples.
#   % (self.n_quantiles, n_samples))

# %%
def objective(trial):
    model = keras.models.Sequential()
    model.add(
        keras.layers.Dense(
            50,
            activation=trial.suggest_categorical("activation", ["relu", "linear", 'swish']),
            input_shape=[21],
            ))
    model.add(
        keras.layers.Dense(10,
        activation=trial.suggest_categorical("activation", ["relu", "linear", 'swish']),)
    )
    model.add(
        keras.layers.Dense(1)
    )
    # defining suggestion for learning rate and optimizer
    lr = trial.suggest_float("lr", 1e-5, 1e-1, log=True)
    optimizer_name = trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])

    if optimizer_name=="Adam":
        optimizer = Adam(learning_rate=lr)
    elif optimizer_name=="RMSprop":
        optimizer = RMSprop(learning_rate=lr)
    elif optimizer_name=="SGD":
        optimizer = SGD(learning_rate=lr)
    
    # compiling model
    model.compile(
        loss="mae", optimizer=trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"])
    )

    #fitting model
    model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        shuffle=True,
        batch_size=32,
        epochs=10,
        verbose=False,
    )

    score = model.evaluate(X_val, y_val, verbose=0)
    return score

# %%
# create Optuna study

study = optuna.create_study(direction="minimize", sampler=TPESampler(multivariate=True))
study.optimize(objective, n_trials=100, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2021-03-01 16:07:05,355] A new study created in memory with name: no-name-c628d375-4e1c-469a-8f06-f16722938c2b
# [I 2021-03-01 16:07:06,103] Trial 0 finished with value: 37.67466354370117 and parameters: {'activation': 'relu', 'lr': 0.00047750770745894424, 'optimizer': 'SGD'}. Best is trial 0 with value: 37.67466354370117.
# [I 2021-03-01 16:07:07,230] Trial 1 finished with value: 38.763145446777344 and parameters: {'activation': 'linear', 'lr': 7.285071246243215e-05, 'optimizer': 'Adam'}. Best is trial 0 with value: 37.67466354370117.
# [I 2021-03-01 16:07:08,127] Trial 2 finished with value: 38.81184387207031 and parameters: {'activation': 'swish', 'lr': 0.07678962027655901, 'optimizer': 'RMSprop'}. Best is trial 0 with value: 37.67466354370117.
# [I 2021-03-01 16:07:09,020] Trial 3 finished with value: 38.96082305908203 and parameters: {'activation': 'swish', 'lr': 0.0012802326620486725, 'optimizer': 'RMSprop'}. Best is trial 0 with value: 37.67466354370117.
 'optimizer': 'RMSprop'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:07,796] Trial 77 finished with value: 23.46963119506836 and parameters: {'activation': 'relu', 'lr': 0.014121491463990691, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:08,644] Trial 78 finished with value: 38.941829681396484 and parameters: {'activation': 'relu', 'lr': 0.0001122093857041307, 'optimizer': 'RMSprop'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:09,379] Trial 79 finished with value: 21.677806854248047 and parameters: {'activation': 'linear', 'lr': 0.002559066946910143, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:10,111] Trial 80 finished with value: 26.156768798828125 and parameters: {'activation': 'linear', 'lr': 0.000455283086050638, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:10,852] Trial 81 finished with value: 22.750581741333008 and parameters: {'activation': 'linear', 'lr': 0.0024576072838383397, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:11,600] Trial 82 finished with value: 29.54246711730957 and parameters: {'activation': 'linear', 'lr': 0.001758405143688947, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:12,716] Trial 83 finished with value: 26.860706329345703 and parameters: {'activation': 'linear', 'lr': 0.0014958529991365072, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:13,529] Trial 84 finished with value: 36.459049224853516 and parameters: {'activation': 'swish', 'lr': 0.0006507581200355733, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:14,268] Trial 85 finished with value: 22.543367385864258 and parameters: {'activation': 'linear', 'lr': 0.003866485793955551, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:14,998] Trial 86 finished with value: 23.629976272583008 and parameters: {'activation': 'linear', 'lr': 0.010516147963520215, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:15,735] Trial 87 finished with value: 24.360782623291016 and parameters: {'activation': 'linear', 'lr': 6.607570320431659e-05, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:16,498] Trial 88 finished with value: 39.33915328979492 and parameters: {'activation': 'linear', 'lr': 0.005961217051528529, 'optimizer': 'Adam'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:17,224] Trial 89 finished with value: 24.267200469970703 and parameters: {'activation': 'linear', 'lr': 0.0065133472351107235, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:17,935] Trial 90 finished with value: 28.259225845336914 and parameters: {'activation': 'linear', 'lr': 0.004056936790156079, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:18,670] Trial 91 finished with value: 28.44908332824707 and parameters: {'activation': 'linear', 'lr': 0.0012994897571418492, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:19,414] Trial 92 finished with value: 26.711881637573242 and parameters: {'activation': 'linear', 'lr': 0.0017412325473178938, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:20,146] Trial 93 finished with value: 25.744232177734375 and parameters: {'activation': 'linear', 'lr': 0.004907733091499681, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:20,908] Trial 94 finished with value: 31.173677444458008 and parameters: {'activation': 'relu', 'lr': 0.0009478405578402373, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:21,660] Trial 95 finished with value: 22.27910041809082 and parameters: {'activation': 'linear', 'lr': 0.004579687338763898, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:22,539] Trial 96 finished with value: 37.187965393066406 and parameters: {'activation': 'linear', 'lr': 0.008009338354137056, 'optimizer': 'RMSprop'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:23,264] Trial 97 finished with value: 21.705793380737305 and parameters: {'activation': 'linear', 'lr': 0.01996053121825833, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:24,057] Trial 98 finished with value: 31.695148468017578 and parameters: {'activation': 'linear', 'lr': 0.012041396502188335, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# [I 2021-03-01 16:08:24,826] Trial 99 finished with value: 27.78544044494629 and parameters: {'activation': 'linear', 'lr': 0.023834275697171142, 'optimizer': 'SGD'}. Best is trial 8 with value: 21.673173904418945.
# Number of finished trials: 100
# Best trial:
#   Value: 21.673173904418945
#   Params:
#     activation: linear
#     lr: 0.00974988432189037
#     optimizer: SGD

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9f2954cd-f149-4d4f-a4b0-a1e3eb6d921f' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
