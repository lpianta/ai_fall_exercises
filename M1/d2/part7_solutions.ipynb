# %%
f = open("./text-files/blakepoems.txt", "r")
if f.mode == "r":
    content = f.read()
    content = content.lower()
    content = content.split()
    word_dict = {}
    for word in content:
        if word in word_dict:
            word_dict[word] += 1
        else:
            word_dict[word] = 1
    sorted_dict = dict(sorted(word_dict.items(), key=lambda item: item[0]))
    print(sorted_dict)
# Out:
# {'"a': 1, '"and': 3, '"and,': 1, '"because': 1, '"break': 1, '"does': 1, '"drop': 1, '"father,': 1, '"follow': 1, '"for': 1, '"frowning,': 1, '"ha,': 2, '"hush,': 1, '"i': 3, '"i\'ve': 1, '"if': 1, '"lo,': 1, '"look': 1, '"lost': 1, '"love': 2, '"no,': 1, '"nought': 1, '"o': 1, '"oh': 1, '"ona,': 1, '"one': 1, '"pipe': 1, '"piper,': 2, '"prisoned': 1, '"selfish': 1, '"such,': 1, '"sweet': 1, '"then': 1, '"they': 1, '"thou': 1, '"turn': 1, '"weep': 1, '"weep!': 2, '"well,': 1, '"what': 1, '"where': 1, '"wrath': 1, '&': 17, "'come": 1, "'twas": 1, '(grave': 1, '--': 9, '1780': 1, '1789]': 1, '[poems': 1, 'a': 126, 'a-sleeping,': 1, 'about': 1, 'abroad': 1, 'abstract': 1, 'ache,': 1, 'admired': 1, 'adona': 1, 'afar,': 1, 'affright': 1, 'after': 2, 'again,': 1, 'again;': 1, 'again;"': 1, 'against': 1, 'age': 1, 'age,': 1, 'aged': 1, 'agree': 1, 'ah': 5, 'ah!': 2, 'air': 2, 'air,': 1, 'air.': 2, 'air:': 1, 'airy': 1, 'alas!': 1, "albion's": 1, 'ale,': 1, 'alehouse': 1, 'all': 36, 'all,': 2, 'all:': 1, 'allay': 1, 'alone': 1, 'altar': 1, 'always': 1, 'am': 14, 'am,': 1, 'am;': 1, 'ambush': 1, 'among': 7, 'among:': 1, 'an': 21, 'ancient': 3, 'and': 340, 'and,': 4, 'angel': 7, 'angel,': 1, 'angel-guarded': 1, 'angels': 1, 'angels,': 1, 'angry': 2, 'annoy,': 1, 'another': 4, "another's": 4, 'answer': 1, 'answer,': 1, 'answerd': 2, 'answerd,': 1, 'answered,': 1, 'answered:': 1, 'anvil?': 1, 'anxious': 1, 'any': 3, 'appall.': 1, 'appals,': 1, 'apparel.': 1, 'appear?': 2, 'appeared': 1, 'appears': 1, 'appendix': 1, 'apple': 1, 'are': 25, 'arise': 4, 'arise,': 3, 'arise;': 2, 'arm': 1, 'arm,': 1, 'armed': 3, 'armed,': 1, 'arms': 1, 'arose': 1, 'around': 3, 'around!': 1, 'around,': 1, 'arrow,': 1, 'arrows': 1, 'art': 6, 'artful': 1, 'as': 16, 'ask': 2, 'asleep.': 1, 'asleep."': 1, 'aspire': 1, 'aspire?': 1, "astonish'd": 1, 'at': 7, 'author': 1, 'away': 8, 'away!': 1, 'away,': 6, 'away.': 4, 'away:': 1, 'away;': 2, 'away?': 2, 'awoke,': 1, 'babe,': 2, 'babes': 2, 'back': 2, 'back,': 1, 'bags': 2, 'baits': 1, 'balmy': 1, 'ban,': 1, 'band': 1, 'bands': 1, 'bandy': 1, 'bane,': 1, 'bank,': 1, 'bar:': 1, 'bard': 1, 'bard,': 1, 'bare,': 2, 'barrel,': 1, 'be': 20, 'be!': 4, 'be;': 1, 'beadles': 1, 'beams': 2, 'beams!': 1, 'bear': 3, 'bear,': 1, 'bear?': 1, 'bearing': 1, 'bears': 1, 'beast,': 1, 'beasts': 2, 'beat,': 1, 'beauty': 5, 'became': 2, 'because': 4, 'become': 1, 'becomes': 2, 'bed': 2, 'bed,': 3, 'bed.': 2, 'bed."': 1, 'been': 2, 'beetle': 1, "beetle's": 1, 'befall': 2, 'before': 5, 'before,': 1, 'before;': 1, 'began': 3, 'beguile.': 2, 'beguiled!': 1, 'beguiled,': 1, 'beguiles.': 1, 'beheld': 1, 'behind,': 1, 'behold': 1, 'bells': 1, "bells'": 1, 'beneath': 2, 'benighted,': 1, 'bereaved': 1, 'beside': 4, 'besides,': 2, 'best': 1, 'betray.': 1, 'bid': 1, 'bind': 2, 'binding': 1, 'binds': 1, 'birch.': 1, 'bird': 2, "bird's": 2, 'birds': 8, "birds'": 1, 'birds,': 2, 'birth': 1, 'black': 5, 'black,': 2, 'black.': 1, 'blackening': 1, 'bladder': 1, 'blade': 1, 'blake': 1, "blake's": 1, 'blake,': 1, 'blake.': 1, 'blasts': 2, 'bleak': 1, 'bleating': 1, 'bless': 3, 'blessing,': 2, 'blights': 1, 'blind': 1, 'blood': 1, 'blossom': 3, 'blossom,': 1, 'blossoms': 3, 'blown': 3, 'blue,': 1, 'blushed': 1, 'bodies': 1, 'bondage': 1, 'bones': 2, 'book': 5, 'book,': 1, 'bore': 5, 'bore.': 1, 'bore;': 1, 'born': 3, 'bosom': 1, 'bosom.': 3, 'both': 6, 'bound': 2, 'bound."': 1, 'bow,': 1, 'bowd': 2, 'bowed': 1, 'bower,': 2, 'bowl?': 1, 'boy': 6, 'boy,': 3, 'boy.': 1, 'boy?': 1, 'boys': 2, 'brain.': 1, 'brain?': 1, 'break': 1, 'breast': 1, 'breast,': 2, 'breast.': 2, 'breath': 2, 'breathed': 1, 'breathing': 1, 'briars': 1, 'bright': 9, 'bright,': 2, 'bright.': 1, 'bright;': 3, 'brings': 1, 'brook': 1, 'brooks:': 1, 'brothers': 1, 'brothers,': 1, 'brought,': 1, 'brows': 1, "bruis'd": 1, 'brush': 1, 'brushed': 1, 'brushes': 1, 'bud': 1, 'buds': 2, 'builds': 2, 'built': 1, 'burned': 2, 'burning': 3, 'burnt': 1, 'bush,': 1, 'but': 36, 'but,': 2, 'butterfly': 1, 'b ...

# %%
f = open("./text-files/blakepoems.txt", "r")
if f.mode == "r":
    content = f.readlines()
    for line in content:
        line = line.lower()
        line = line.split()
        for word in line:
            if word in word_dict:
                word_dict[word] += 1
            else:
                word_dict[word] = 1
    print(word_dict)
    sorted_dict = dict(sorted(word_dict.items(), key=lambda item: item[0]))
    #print(sorted_dict)
# Out:
# {'har': 1}
